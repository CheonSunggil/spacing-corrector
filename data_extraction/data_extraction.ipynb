# %%
import argparse
from datetime import datetime
from Korpora import Korpora
from s3_utils import S3Client

# %%
corpus = 'kowikitext'

# %%
s3_client = S3Client('local')
FOLDER_NAME = "spacing_corrector"

RAW_DATA_PREFIX = "{}/data/raw/".format(FOLDER_NAME)
raw_data_save_key = "{}{}.pkl".format(RAW_DATA_PREFIX, corpus)
#import sys
#from io import StringIO

#sys.stdin = StringIO('yes')    
data = Korpora.load(corpus)
data = data.get_all_texts()
# Out:
#     Korpora 는 다른 분들이 연구 목적으로 공유해주신 말뭉치들을
#     손쉽게 다운로드, 사용할 수 있는 기능만을 제공합니다.
#
#     말뭉치들을 공유해 주신 분들에게 감사드리며, 각 말뭉치 별 설명과 라이센스를 공유 드립니다.
#     해당 말뭉치에 대해 자세히 알고 싶으신 분은 아래의 description 을 참고,
#     해당 말뭉치를 연구/상용의 목적으로 이용하실 때에는 아래의 라이센스를 참고해 주시기 바랍니다.
#
#     # Description
#     Author : Hyunjoong Kim lovit@github
#     Repository : https://github.com/lovit/kowikitext
#     References :
#
#     한국어 위키피디아의 덤프 데이터를 바탕을 제작한 wikitext 형식의 텍스트 파일입니다.
#     학습 및 평가를 위하여 위키페이지 별로 train (99%), dev (0.5%), test (0.5%) 로 나뉘어져있습니다.
#
#
#     # License
#     CC-BY-SA 3.0 which kowiki dump dataset is licensed
#
# [Korpora] Corpus `kowikitext` is already installed at C:\Users\chkrd\Korpora\kowikitext\kowikitext_20200920.train.zip
# [Korpora] Corpus `kowikitext` is already installed at C:\Users\chkrd\Korpora\kowikitext\kowikitext_20200920.train
# [Korpora] Corpus `kowikitext` is already installed at C:\Users\chkrd\Korpora\kowikitext\kowikitext_20200920.test.zip
# ...

# %%
len(data)
# Out:
# 3545515

# %%
s3_client.upload_data(raw_data_save_key,data)
# Out:
# KeyboardInterrupt

# %%
raw_data = kowiki.get_all_texts()

# %%
s3_client = S3Client('live')

# %%
s3_client.upload_data('spacing-corrector/data/raw/raw_today.pkl',corpus_list)
# Out:
# 3545515

# %%
def split_sentences(corpus_list):
    result = list()
    for i in tqdm(corpus_list) :
        result += i.split('\n')
    result = list(set(result))
    result.remove('')
    return result

# %%
def data_aggregation(corpus_list):
    result = list()
    print(corpus_list)
    for corpus in corpus_list :
        print(corpus)
        result = result + corpus.get_all_texts()
    
    return result

# %%
data = kowiki.get_all_texts()

# %%
data = split_sentences(data)
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 3545515/3545515 [00:02<00:00, 1298444.36it/s]

# %%
np.max([len(i) for i in data])
# Out:
# 68917

# %%
def split_sentences

# %%
kss.split_sentences(data[2])
# Out:
# ['-- A redirect exists, but it is a general redirect and not for any specific season section.']

# %%
kss.split_sentences(data[1])
# Out:
# ['김기복(金基福, 1944년 5월 22일 ~ )은 대한민국의 전 축구 선수 및 감독이다.', '황해도 출신이다.']

# %%
corpus_list = data_aggregation([kowiki, namu])
# Out:
# [<Korpora.korpus_kowiki.KowikiTextKorpus object at 0x000002ABE2BD0C40>, <Korpora.korpus_namuwiki.NamuwikiTextKorpus object at 0x000002ABE2BD0A60>]
# KowikiTextKorpus
#     Author : Hyunjoong Kim lovit@github
#     Repository : https://github.com/lovit/kowikitext
#     References :
#
#     한국어 위키피디아의 덤프 데이터를 바탕을 제작한 wikitext 형식의 텍스트 파일입니다.
#     학습 및 평가를 위하여 위키페이지 별로 train (99%), dev (0.5%), test (0.5%) 로 나뉘어져있습니다.
#
#
# Attributes
# ----------
# KowikiText.test: size=17640
#   - KowikiText.test.texts : list[str]
#   - KowikiText.test.pairs : list[str]
# KowikiText.dev: size=17141
#   - KowikiText.dev.texts : list[str]
#   - KowikiText.dev.pairs : list[str]
#
# NamuwikiTextKorpus
#     Author : Hyunjoong Kim lovit@github
#     Repository : https://github.com/lovit/namuwikitext
#     References :
#
#     나무위키의 덤프 데이터를 바탕을 제작한 wikitext 형식의 텍스트 파일입니다.
#     학습 및 평가를 위하여 위키페이지 별로 train (99%), dev (0.5%), test (0.5%) 로 나뉘어져있습니다.
#
#
# Attributes
# ----------
# ...

# %%
s3_client = S3Client('live')

# %%
s3_client.upload_data('spacing-corrector/data/raw/raw_today.pkl',corpus_list)

# %%
corpus_list = split_sentences(corpus_list)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 74835/74835 [00:00<00:00, 946998.44it/s]

# %%
# Out:
# ['클로이 범죄의 제국',
#  '허블 우주 망원경이 촬영한 M100. 왼쪽이 보정 전, 오른쪽이 보정 후.',
#  '체포당했을때 강종하는건 기본으로 깔고 갔었죠. RP 도중 이 행위를 하실 경우 제재를 받으실 수 있습니다.',
#  '"깜박깜박 이 가슴 태우며" 보구 "시키시는 대로." "지금 춤추도록 하죠." 보구 발동',
#  '승리 확률 증가.',
#  "대한민국에서는 1982년 5월 15일 전길남 박사의 주도로 서울대학교와 한국전자기술연구소 ( 현 ETRI ) 사이에 최초로 인터넷 연결을 성공했다. 1984년에는 공중정보통신망 ( PSDN ) 을 개통하여 일본에 이어 아시아에서 두 번째로 패킷보유망을 보유한 국가가 됐다. 1985년 최초의 PC통신 '천리안' 서비스가 문을 열었으며, 1994년에는 한국통신 ( 현 KT ) 에서 코넷 ( KORNET ) 이란 이름으로 WWW기반의 인터넷 상용서비스를 최초로 시작하였다.#",
#  '「미풍」「서풍」을 의미하는 영어의 유래.',
#  '*A02 기타 살모넬라 감염',
#  ': 〈오에도전사 토노사맨〉의 프로듀서. 담뱃대를 애용한다.',
# ...

# %%
import math
import time
from datetime import datetime, timedelta

start = time.time()
math.factorial(1234567)
end = time.time()


sec = (end - start)
result = timedelta(seconds=sec)
print(result)

# result_list = str(timedelta(seconds=sec)).split(".")
# print(result_list[0])
# Out:
# 0:00:07.968823

# %%
timedelta
# Out:
# datetime.timedelta
